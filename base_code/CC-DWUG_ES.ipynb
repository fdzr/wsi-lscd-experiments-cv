# %%
from datetime import datetime
from functools import partial

from _correlation import cluster_correlation_search
import clustering
from common_generate_predictions import load_data, grid_search_without_nclusters, get_gold_data
import networkx as nx
import numpy as np

# %%
def get_clusters(adj_matrix, hyperparameters, seed=0):
    use_disconnected_edges = hyperparameters.pop("use_disconnected_edges", False)
    G = clustering._adjacency_matrix_to_nxgraph(
        adj_matrix,
        use_disconnected_edges=use_disconnected_edges,
    )
    hyperparameters.pop("use_disconnected_edges", None)

    clusters = clustering.correlation_clustering(G, **hyperparameters)
    return clustering._convert_graph_cluster_list_set_to_list(G, clusters)

# %%
method = "cc"
path_to_data = "../mixtral-8xtb-v0.1/v1/"
is_cross_validation=False
path_to_experiments = {
    True: "../cv-experiments/" + f"{method}/" + "{kfold}_fold",
    False: "../no-cv-experiments/" + f"{method}/" + "{kfold}"
}

# %%
def generate_hyperparameter_combinations_for_cc():
    combinations = []

    for number_sense in [10]:
        for attempt in [2000]:
            for iteration in [50000]:
                combinations.append(
                    {
                        "max_attempts": attempt,
                        "max_iters": iteration,
                        "max_senses": number_sense,
                    }
                )

    return combinations

# %%
start_time = datetime.now()


grid_search_without_nclusters(
    partial(load_data, path_to_data),
    get_clusters,
    generate_hyperparameter_combinations_for_cc(),
    fill_diagonal=True,
    normalize=True,
    method=method,
)

print(f"Elapsed time: {datetime.now() - start_time}")
# Out:
# 2024-06-19 16:25:44,347 - INFO - loading data ...
# 2024-06-19 16:25:44,563 - INFO - data loaded ...
# 2024-06-19 16:25:44,563 - INFO - training cc method ...
# 2024-06-19 16:25:44,563 - INFO - 1/4 - {'fill_diagonal': True, 'normalize': False, 'model_hyperparameters': {'max_attempts': 2000, 'max_iters': 50000, 'max_senses': 10}}
# 2024-06-19 16:25:44,564 - INFO - get predictions without nclusters ...
# 2024-06-19 16:25:44,569 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,590 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,591 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,602 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,605 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,626 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,626 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,635 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,637 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,659 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,659 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,667 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,670 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,691 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,692 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,701 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,703 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,724 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,725 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,733 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,736 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,758 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,758 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,767 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,769 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,791 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,791 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,800 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,803 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,824 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,825 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,833 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,836 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,858 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,858 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,867 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,869 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,892 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,893 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,909 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,913 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,947 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,947 - INFO - calculating predictions ...
# 2024-06-19 16:25:44,963 - INFO - predictions calculated ...
# 2024-06-19 16:25:44,966 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:44,992 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:44,992 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,002 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,004 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,026 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,026 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,036 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,038 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,060 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,060 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,069 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,071 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,092 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,092 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,101 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,103 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,125 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,125 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,134 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,136 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,158 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,158 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,166 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,169 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,190 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,191 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,199 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,202 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,223 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,223 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,232 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,235 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,256 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,256 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,265 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,267 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,289 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,289 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,297 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,300 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,321 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,321 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,330 - INFO - predictions calculated ...
# 2024-06-19 16:25:45,333 - INFO - building adjacency matrix ...
# 2024-06-19 16:25:45,354 - INFO - adjacency matrix built ...
# 2024-06-19 16:25:45,354 - INFO - calculating predictions ...
# 2024-06-19 16:25:45,363 - INFO - predictions calculated ...
# 2024-06-19 16:25:45